# %% [markdown]
# ## rename video and srt files according to excel input file

# %%
import pandas as pd
import os

# Specify the path to your Excel file
excel_file_path = r"C:\Users\Sean\OneDrive - Virginia Tech\Documents\SGC_Teaching_MSE_2034_D2L\vscode_brightspace_development\brightspace\materials_science_renderings\assets\media\file_list.xlsx"

def rename_files(excel_path):
    try:
        data = pd.read_excel(excel_path)
    except Exception as e:
        print(f"Failed to read the Excel file: {e}")
        return

    for index, row in data.iterrows():
        directory_path = row['directory path']
        video_file_name = row['video file name']
        srt_file_name = row['srt file name']
        new_name = row['rename']

        if pd.isna(new_name):
            print(f"Missing new name in row {index}: skipping this row.")
            continue

        # Process video file if it exists
        if not pd.isna(video_file_name):
            video_path = os.path.join(directory_path, video_file_name)
            video_extension = os.path.splitext(video_file_name)[1]
            new_video_path = os.path.join(directory_path, new_name + video_extension)
            if os.path.exists(video_path):
                os.rename(video_path, new_video_path)
                print(f"Renamed '{video_file_name}' to '{new_name + video_extension}'")
            else:
                print(f"Video file not found: {video_path}")

        # Process subtitle file if it exists
        if not pd.isna(srt_file_name):
            srt_path = os.path.join(directory_path, srt_file_name)
            srt_extension = os.path.splitext(srt_file_name)[1]
            new_srt_path = os.path.join(directory_path, new_name + srt_extension)
            if os.path.exists(srt_path):
                os.rename(srt_path, new_srt_path)
                print(f"Renamed '{srt_file_name}' to '{new_name + srt_extension}'")
            else:
                print(f"SRT file not found: {srt_path}")

# Specify the path to your Excel file

rename_files(excel_file_path)
# Out:
# Renamed 'intro mse course.mp4' to '00.01.welcome_intro.mp4'
# Renamed 'intro course.srt' to '00.01.welcome_intro.srt'
# Renamed 'Chapter_1_Introduction_to_MSE_(Source).mp4' to '01.01_intro.mp4'
# Renamed '1 intro.srt' to '01.01_intro.srt'
# Renamed 'Chapter_2_Bonding_(Source).mp4' to '02.01_bonding.mp4'
# Renamed '2 bonding.srt' to '02.01_bonding.srt'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# Renamed 'Chap 3 Struc of Crystal Solids part 1.mp4' to '03.01_structures.mp4'
# Renamed '3 1.srt' to '03.01_structures.srt'
# Renamed 'Chap_3_lecture_2__FCC_vs_HCP_packing_(Source).mp4' to '03.02_structures.mp4'
# Renamed '3 2.srt' to '03.02_structures.srt'
# Renamed 'Chapter_3_lecture_3__Point_Coordinates_(Source).mp4' to '03.03_structures.mp4'
# Renamed '3 3.srt' to '03.03_structures.srt'
# Renamed 'Chapter_3_lecture_4__Miller_indices_for_directions_and_planes_(Source).mp4' to '03.04_structures.mp4'
# Renamed '3 4.srt' to '03.04_structures.srt'
# Renamed 'Chapter_3_lecture_5__atom_placement_on_planes_(Source).mp4' to '03.05_structures.mp4'
# Renamed '3 5.srt' to '03.05_structures.srt'
# Renamed 'Theoretical Density.mp4' to '03.06_structures.mp4'
# Renamed '3 theor dens.srt' to '03.06_structures.srt'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# Renamed 'Chapter_4_Defects_in_Crystalline_Materials__Point_Defects_(Source).mp4' to '04.01_defects.mp4'
# Renamed '4 point.srt' to '04.01_defects.srt'
# Renamed 'Chapter_4_Defects_in_Crystalline_Materials__Line_Defects_(Source).mp4' to '04.02_defects.mp4'
# Renamed '4 line.srt' to '04.02_defects.srt'
# Renamed 'Chapter_4_Defects_in_Crystalline_Materials__Interfacial_Defects_(Source).mp4' to '04.03_defects.mp4'
# Renamed '4 interfacial.srt' to '04.03_defects.srt'
# Renamed 'Chapter_5_Diffusion_part_1__Mechanism_(Source).mp4' to '05.01_diffusion.mp4'
# Renamed 'Chapter 5 part 1.srt' to '05.01_diffusion.srt'
# Renamed 'Chapter_5_Diffusion_part_2__Importance_(Source).mp4' to '05.02_diffusion.mp4'
# Renamed 'Chapter 5 part 2.srt' to '05.02_diffusion.srt'
# Renamed 'Chapter_5_Diffusion_part_3__steady_state_(Source).mp4' to '05.03_diffusion.mp4'
# Renamed 'Chapter 5 part 3.srt' to '05.03_diffusion.srt'
# Renamed 'Chapter_5_Diffusion_part_4__Temperature_(Source).mp4' to '05.04.diffusion.mp4'
# Renamed 'Chap 5 part 4.srt' to '05.04.diffusion.srt'
# Renamed 'Chapter_5_Diffusion_part_5__semi-infinite_(Source).mp4' to '05.05_diffusion.mp4'
# Renamed 'Chaper 5 part 5.srt' to '05.05_diffusion.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_1__stress_strain_(Source).mp4' to '06.01_mech.mp4'
# Renamed 'Chap 6 part 1.srt' to '06.01_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_2__elastic_behavior_(Source).mp4' to '06.02_mech.mp4'
# Renamed 'Chap 6 part 2.srt' to '06.02_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_3__Atomic_perspective_(Source).mp4' to '06.03_mech.mp4'
# Renamed 'Chapt 6 part 3.srt' to '06.03_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_4__anisotropy_of_Elastic_modulus_(Source).mp4' to '06.04_mech.mp4'
# Renamed 'Chap 6 part 4.srt' to '06.04_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_5__isotropic_elastic_constants_(Source).mp4' to '06.05_mech.mp4'
# Renamed 'Chap 6 part 5.srt' to '06.05_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_6__plastic_deformation_(Source).mp4' to '06.06_mech.mp4'
# Renamed 'Chap 6 part 6.srt' to '06.06_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_7__real_stress_strain_data_(Source).mp4' to '06.07_mech.mp4'
# Renamed 'Chap 6 part 7.srt' to '06.07_mech.srt'
# Renamed 'Chapter_6_Mechanical_Behavior_part_8__hardness_(Source).mp4' to '06.08_mech.mp4'
# Renamed 'Chap 6 part 8.srt' to '06.08_mech.srt'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# An error occurred: join() argument must be str, bytes, or os.PathLike object, not 'float'
# Renamed 'CES Edupack advanced plotting.mp4' to '00.02_supp.mp4'
# Renamed 'ces advanced plotting.srt' to '00.02_supp.srt'
# Renamed 'Excel_-_scatter_plot_(Source).mp4' to '00.03_supp.mp4'
# Renamed 'excel scatter.srt' to '00.03_supp.srt'
